# %% [markdown]
# https://www.kaggle.com/code/thebrownviking20/intro-to-keras-with-breast-cancer-data-ann/notebook

# %% [markdown]
# # Aim
# This is a small yet useful kernel for providing an introduction to **Artificial Neural Networks** for people who want to begin their journey into the field of **deep learning**. For this, I have used Keras which is a high-level Neural Networks API built on top of low level neural networks APIs like Tensorflow and Theano. As it is high-level, many things are already taken care of therefore it is easy to work with and a great tool to start with. [Here's the documentation for keras](https://keras.io/)
#
# # What is Deep learning?
# Deep Learning is a subfield of machine learning concerned with algorithms inspired by the structure and function of the brain called artificial neural networks. Deep learning is a machine learning technique that teaches computers to do what comes naturally to humans: learn by example. Deep learning is a key technology behind driverless cars, enabling them to recognize a stop sign, or to distinguish a pedestrian from a lamppost. It is the key to voice control in consumer devices like phones, tablets, TVs, and hands-free speakers. Deep learning is getting lots of attention lately and for good reason. It’s achieving results that were not possible before.
#
#
# # What are artificial neural networks?
# An artificial neuron network (ANN) is a computational model based on the structure and functions of biological neural networks. Information that flows through the network affects the structure of the ANN because a neural network changes - or learns, in a sense - based on that input and output. ANNs are considered nonlinear statistical data modeling tools where the complex relationships between inputs and outputs are modeled or patterns are found. ANN is also known as a neural network.

# %% [markdown]
# <img src="https://cdn-images-1.medium.com/max/1000/1*ZX05x1xYgaVoa4Vn2kKS9g.png">

# %% [markdown]
# A single neuron is known as a perceptron. It consists of a layer of inputs(corresponds to columns of a dataframe). Each input has a weight which controls the magnitude of an input.
# The summation of the products of these input values and weights is fed to the activation function. Activation functions are really important for a Artificial Neural Network to learn and make sense of something really complicated and Non-linear complex functional mappings between the inputs and response variable.
#
# They introduce non-linear properties to our Network.Their main purpose is to convert a input signal of a node in a A-NN to an output signal. That output signal now is used as a input in the next layer in the stack.  Specifically in A-NN we do the sum of products of inputs(X) and their corresponding Weights(W) and apply a Activation function f(x) to it to get the output of that layer and feed it as an input to the next layer. [Refer to this article for more info.](https://towardsdatascience.com/activation-functions-and-its-types-which-is-better-a9a5310cc8f)
# <img src="https://cdnpythonmachinelearning.azureedge.net/wp-content/uploads/2017/09/Single-Perceptron.png">
# **Concept of backpropagation** - Backpropagation, short for "backward propagation of errors," is an algorithm for supervised learning of artificial neural networks using gradient descent. Given an artificial neural network and an error function, the method calculates the gradient of the error function with respect to the neural network's weights. It is a generalization of the delta rule for perceptrons to multilayer feedforward neural networks.
# <img src="https://www.researchgate.net/profile/Hassan_Al-Haj_Ibrahim/publication/235338024/figure/fig6/AS:299794191929349@1448487913220/Flow-chart-for-the-back-propagation-BP-learning-algorithm.png">
# **Gradient Descent** - To explain Gradient Descent I’ll use the classic mountaineering example. Suppose you are at the top of a mountain, and you have to reach a lake which is at the lowest point of the mountain (a.k.a valley). A twist is that you are blindfolded and you have zero visibility to see where you are headed. So, what approach will you take to reach the lake? The best way is to check the ground near you and observe where the land tends to descend. This will give an idea in what direction you should take your first step. If you follow the descending path, it is very likely you would reach the lake. [Refer to this article for more information.](https://www.analyticsvidhya.com/blog/2017/03/introduction-to-gradient-descent-algorithm-along-its-variants/)

# %% [markdown]
# About Breast Cancer Wisconsin (Diagnostic) Data Set
# Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass. They describe characteristics of the cell nuclei present in the image. n the 3-dimensional space is that described in: [K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server: ftp ftp.cs.wisc.edu cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# Also can be found on UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29
#
# Attribute Information:
#
# 1) ID number 2) Diagnosis (M = malignant, B = benign) 3-32)
#
# Ten real-valued features are computed for each cell nucleus:
#
# a) radius (mean of distances from center to points on the perimeter) b) texture (standard deviation of gray-scale values) c) perimeter d) area e) smoothness (local variation in radius lengths) f) compactness (perimeter^2 / area - 1.0) g) concavity (severity of concave portions of the contour) h) concave points (number of concave portions of the contour) i) symmetry j) fractal dimension ("coastline approximation" - 1)
#
# The mean, standard error and "worst" or largest (mean of the three largest values) of these features were computed for each image, resulting in 30 features. For instance, field 3 is Mean Radius, field 13 is Radius SE, field 23 is Worst Radius.
#
# All feature values are recoded with four significant digits.
#
# Missing attribute values: none
#
# Class distribution: 357 benign, 212 malignant

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Deep Learning for Computer Vision/Notebooks - ANN - DNN/2.Breast cancer classification
# Out:
# /content/drive/MyDrive/Machine learning 2024/Notebooks - ANN - DNN/2.Breast cancer classification

# %%
ls
# Out:
# data.csv  intro-to-keras-with-breast-cancer-data-ann.ipynb

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Importing data
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
X = data.iloc[:, 2:].values
y = data.iloc[:, 1].values

# Encoding categorical data
from sklearn.preprocessing import LabelEncoder
labelencoder_X_1 = LabelEncoder()
y = labelencoder_X_1.fit_transform(y)

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)

#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (512, 30)

# %% [markdown]
# **Now that we have prepared data, we will import Keras and its packages.**

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
# Need Dense layers for this task of breast cancer
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 30))
# Adding dropout to prevent overfitting
classifier.add(Dropout(rate = 0.1))

# Adding the second hidden layer
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
# Adding dropout to prevent overfitting
classifier.add(Dropout(rate = 0.1))

# Adding the second hidden layer
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
# Adding dropout to prevent overfitting
classifier.add(Dropout(rate = 0.1))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))  # 0 - 1   >=0.5 ? 1 , 0
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
classifier.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,057 (4.13 KB)
#  Trainable params: 1,057 (4.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# input_dim - number of columns of the dataset
#
# output_dim - number of outputs to be fed to the next layer, if any
#
# activation - activation function which is ReLU in this case
#
# init - the way in which weights should be provided to an ANN
#
# When you use **kernel_initializer='uniform'**, it means that the weights of the layer are initialized by drawing random values from a uniform distribution. Specifically, the weights are initialized with values from a uniform distribution within a specific

# %% [markdown]
# output_dim is 1 as we want only 1 output from the final layer.
#
# Sigmoid function is used when dealing with classfication problems with 2 types of results.(Submax function is used for 3 or more classification results)
# <img src="https://cdn-images-1.medium.com/max/1000/1*Xu7B5y9gp0iL5ooBj7LtWw.png">

# %%
# Compiling the ANN
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Optimizer is chosen as adam for gradient descent.
#
# Binary_crossentropy is the loss function used.
#
# Cross-entropy loss, or log loss, measures the performance of a classification model whose output is a probability value between 0 and 1. Cross-entropy loss increases as the predicted probability diverges from the actual label. So predicting a probability of .012 when the actual observation label is 1 would be bad and result in a high loss value. A perfect model would have a log loss of 0. [More about this](http://ml-cheatsheet.readthedocs.io/en/latest/loss_functions.html)

# %%
# Fitting the ANN to the Training set
history=classifier.fit(X_train, y_train,validation_split=0.2, batch_size=32, epochs=200)
# Long scroll ahead but worth
# The batch size and number of epochs have been set using trial and error. Still looking for more efficient ways. Open to suggestions.
# Out:
# Epoch 1/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 323ms/step - accuracy: 0.6161 - loss: 0.6923 - val_accuracy: 0.6019 - val_loss: 0.6914
# Epoch 2/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6357 - loss: 0.6895 - val_accuracy: 0.6019 - val_loss: 0.6875
# Epoch 3/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6357 - loss: 0.6824 - val_accuracy: 0.6117 - val_loss: 0.6763
# Epoch 4/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7090 - loss: 0.6630 - val_accuracy: 0.8155 - val_loss: 0.6456
# Epoch 5/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8753 - loss: 0.6127 - val_accuracy: 0.9612 - val_loss: 0.5725
# Epoch 6/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9535 - loss: 0.5193 - val_accuracy: 0.9806 - val_loss: 0.4421
# Epoch 7/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9511 - loss: 0.3781 - val_accuracy: 0.9806 - val_loss: 0.2924
# Epoch 8/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9609 - loss: 0.2527 - val_accuracy: 0.9903 - val_loss: 0.1799
# Epoch 9/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9535 - loss: 0.1844 - val_accuracy: 0.9903 - val_loss: 0.1175
# Epoch 10/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9682 - loss: 0.1407 - val_accuracy: 0.9903 - val_loss: 0.0874
# Epoch 11/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9707 - loss: 0.1180 - val_accuracy: 0.9806 - val_loss: 0.0731
# Epoch 12/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9756 - loss: 0.1084 - val_accuracy: 0.9806 - val_loss: 0.0640
# Epoch 13/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9731 - loss: 0.0975 - val_accuracy: 0.9806 - val_loss: 0.0562
# Epoch 14/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9804 - loss: 0.0849 - val_accuracy: 0.9806 - val_loss: 0.0528
# Epoch 15/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9756 - loss: 0.0826 - val_accuracy: 0.9806 - val_loss: 0.0499
# Epoch 16/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9804 - loss: 0.0809 - val_accuracy: 0.9806 - val_loss: 0.0446
# Epoch 17/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9780 - loss: 0.0808 - val_accuracy: 0.9806 - val_loss: 0.0418
# Epoch 18/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9829 - loss: 0.0705 - val_accuracy: 0.9806 - val_loss: 0.0389
# Epoch 19/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9804 - loss: 0.0757 - val_accuracy: 0.9806 - val_loss: 0.0372
# Epoch 20/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9780 - loss: 0.0746 - val_accuracy: 0.9806 - val_loss: 0.0362
# Epoch 21/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9804 - loss: 0.0685 - val_accuracy: 0.9806 - val_loss: 0.0362
# Epoch 22/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9829 - loss: 0.0701 - val_accuracy: 0.9903 - val_loss: 0.0334
# Epoch 23/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9756 - loss: 0.0690 - val_accuracy: 0.9903 - val_loss: 0.0321
# Epoch 24/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9829 - loss: 0.0704 - val_accuracy: 0.9903 - val_loss: 0.0305
# Epoch 25/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9804 - loss: 0.0598 - val_accuracy: 0.9903 - val_loss: 0.0298
# Epoch 26/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9804 - loss: 0.0755 - val_accuracy: 0.9903 - val_loss: 0.0283
# Epoch 27/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9829 - loss: 0.0626 - val_accuracy: 0.9903 - val_loss: 0.0276
# Epoch 28/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9804 - loss: 0.0659 - val_accuracy: 0.9903 - val_loss: 0.0277
# Epoch 29/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9829 - loss: 0.0631 - val_accuracy: 0.9903 - val_loss: 0.0266
# Epoch 30/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9804 - loss: 0.0580 - val_accuracy: 0.9903 - val_loss: 0.0260
# Epoch 31/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9829 - loss: 0.0572 - val_accuracy: 0.9903 - val_loss: 0.0248
# Epoch 32/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9829 - loss: 0.0617 - val_accuracy: 0.9903 - val_loss: 0.0239
# Epoch 33/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9853 - loss: 0.0572 - val_accuracy: 0.9903 - val_loss: 0.0241
# Epoch 34/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9829 - loss: 0.0591 - val_accuracy: 1.0000 - val_loss: 0.0222
# Epoch 35/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0551 - val_accuracy: 1.0000 - val_loss: 0.0212
# Epoch 36/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9853 - loss: 0.0545 - val_accuracy: 1.0000 - val_loss: 0.0207
# Epoch 37/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9829 - loss: 0.0599 - val_accuracy: 1.0000 - val_loss: 0.0211
# Epoch 38/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0549 - val_accuracy: 0.9903 - val_loss: 0.0217
# Epoch 39/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0469 - val_accuracy: 0.9903 - val_loss: 0.0227
# Epoch 40/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0459 - val_accuracy: 1.0000 - val_loss: 0.0212
# Epoch 41/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0532 - val_accuracy: 1.0000 - val_loss: 0.0210
# Epoch 42/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0455 - val_accuracy: 1.0000 - val_loss: 0.0191
# Epoch 43/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0510 - val_accuracy: 1.0000 - val_loss: 0.0186
# Epoch 44/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9878 - loss: 0.0451 - val_accuracy: 1.0000 - val_loss: 0.0193
# Epoch 45/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9902 - loss: 0.0478 - val_accuracy: 0.9903 - val_loss: 0.0202
# Epoch 46/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0483 - val_accuracy: 0.9903 - val_loss: 0.0205
# Epoch 47/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0510 - val_accuracy: 1.0000 - val_loss: 0.0186
# Epoch 48/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0503 - val_accuracy: 1.0000 - val_loss: 0.0170
# Epoch 49/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0463 - val_accuracy: 1.0000 - val_loss: 0.0178
# Epoch 50/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0428 - val_accuracy: 0.9903 - val_loss: 0.0185
# Epoch 51/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9829 - loss: 0.0462 - val_accuracy: 1.0000 - val_loss: 0.0173
# Epoch 52/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0516 - val_accuracy: 0.9903 - val_loss: 0.0194
# Epoch 53/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9829 - loss: 0.0502 - val_accuracy: 1.0000 - val_loss: 0.0168
# Epoch 54/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9878 - loss: 0.0455 - val_accuracy: 1.0000 - val_loss: 0.0162
# Epoch 55/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0447 - val_accuracy: 1.0000 - val_loss: 0.0162
# Epoch 56/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0427 - val_accuracy: 1.0000 - val_loss: 0.0148
# Epoch 57/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0401 - val_accuracy: 1.0000 - val_loss: 0.0147
# Epoch 58/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0365 - val_accuracy: 1.0000 - val_loss: 0.0142
# Epoch 59/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9853 - loss: 0.0442 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 60/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0423 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 61/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0379 - val_accuracy: 1.0000 - val_loss: 0.0142
# Epoch 62/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9878 - loss: 0.0365 - val_accuracy: 1.0000 - val_loss: 0.0147
# Epoch 63/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0449 - val_accuracy: 1.0000 - val_loss: 0.0141
# Epoch 64/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0326 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 65/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0405 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 66/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0434 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 67/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0398 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 68/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0394 - val_accuracy: 1.0000 - val_loss: 0.0112
# Epoch 69/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9853 - loss: 0.0406 - val_accuracy: 1.0000 - val_loss: 0.0132
# Epoch 70/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0354 - val_accuracy: 1.0000 - val_loss: 0.0129
# Epoch 71/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0368 - val_accuracy: 1.0000 - val_loss: 0.0109
# Epoch 72/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0456 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 73/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0356 - val_accuracy: 1.0000 - val_loss: 0.0119
# Epoch 74/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0390 - val_accuracy: 1.0000 - val_loss: 0.0131
# Epoch 75/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9853 - loss: 0.0431 - val_accuracy: 1.0000 - val_loss: 0.0131
# Epoch 76/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0340 - val_accuracy: 0.9903 - val_loss: 0.0132
# Epoch 77/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9853 - loss: 0.0382 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 78/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0405 - val_accuracy: 1.0000 - val_loss: 0.0129
# Epoch 79/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9878 - loss: 0.0345 - val_accuracy: 0.9903 - val_loss: 0.0132
# Epoch 80/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0381 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 81/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0331 - val_accuracy: 1.0000 - val_loss: 0.0102
# Epoch 82/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0345 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 83/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0314 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 84/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9902 - loss: 0.0341 - val_accuracy: 1.0000 - val_loss: 0.0104
# Epoch 85/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9902 - loss: 0.0314 - val_accuracy: 1.0000 - val_loss: 0.0108
# Epoch 86/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9902 - loss: 0.0322 - val_accuracy: 1.0000 - val_loss: 0.0109
# Epoch 87/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9878 - loss: 0.0338 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 88/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9927 - loss: 0.0245 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 89/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9927 - loss: 0.0265 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 90/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9927 - loss: 0.0331 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 91/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9902 - loss: 0.0284 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 92/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9902 - loss: 0.0396 - val_accuracy: 1.0000 - val_loss: 0.0127
# Epoch 93/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9878 - loss: 0.0372 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 94/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9927 - loss: 0.0249 - val_accuracy: 1.0000 - val_loss: 0.0105
# Epoch 95/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9927 - loss: 0.0265 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 96/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9927 - loss: 0.0296 - val_accuracy: 1.0000 - val_loss: 0.0109
# Epoch 97/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9927 - loss: 0.0275 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 98/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9902 - loss: 0.0275 - val_accuracy: 1.0000 - val_loss: 0.0152
# Epoch 99/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9878 - loss: 0.0281 - val_accuracy: 1.0000 - val_loss: 0.0147
# Epoch 100/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9927 - loss: 0.0217 - val_accuracy: 1.0000 - val_loss: 0.0141
# Epoch 101/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9927 - loss: 0.0228 - val_accuracy: 1.0000 - val_loss: 0.0132
# Epoch 102/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0268 - val_accuracy: 1.0000 - val_loss: 0.0120
# Epoch 103/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0400 - val_accuracy: 1.0000 - val_loss: 0.0138
# Epoch 104/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0231 - val_accuracy: 0.9903 - val_loss: 0.0151
# Epoch 105/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0221 - val_accuracy: 1.0000 - val_loss: 0.0151
# Epoch 106/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0271 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 107/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0269 - val_accuracy: 1.0000 - val_loss: 0.0123
# Epoch 108/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0257 - val_accuracy: 1.0000 - val_loss: 0.0133
# Epoch 109/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9878 - loss: 0.0302 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 110/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0219 - val_accuracy: 1.0000 - val_loss: 0.0102
# Epoch 111/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0247 - val_accuracy: 1.0000 - val_loss: 0.0095
# Epoch 112/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9878 - loss: 0.0243 - val_accuracy: 1.0000 - val_loss: 0.0088
# Epoch 113/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0291 - val_accuracy: 1.0000 - val_loss: 0.0104
# Epoch 114/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0198 - val_accuracy: 1.0000 - val_loss: 0.0100
# Epoch 115/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9902 - loss: 0.0295 - val_accuracy: 0.9903 - val_loss: 0.0112
# Epoch 116/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0229 - val_accuracy: 1.0000 - val_loss: 0.0095
# Epoch 117/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0211 - val_accuracy: 0.9903 - val_loss: 0.0100
# Epoch 118/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0250 - val_accuracy: 0.9903 - val_loss: 0.0096
# Epoch 119/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0204 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 120/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0155 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 121/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0202 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 122/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0177 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 123/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9927 - loss: 0.0248 - val_accuracy: 0.9903 - val_loss: 0.0089
# Epoch 124/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0187 - val_accuracy: 0.9903 - val_loss: 0.0098
# Epoch 125/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0180 - val_accuracy: 0.9903 - val_loss: 0.0106
# Epoch 126/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0256 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 127/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0199 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 128/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0141 - val_accuracy: 0.9903 - val_loss: 0.0109
# Epoch 129/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0217 - val_accuracy: 0.9903 - val_loss: 0.0120
# Epoch 130/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0129 - val_accuracy: 0.9903 - val_loss: 0.0094
# Epoch 131/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9976 - loss: 0.0155 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 132/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9976 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 133/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9976 - loss: 0.0136 - val_accuracy: 0.9903 - val_loss: 0.0094
# Epoch 134/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0114 - val_accuracy: 0.9903 - val_loss: 0.0102
# Epoch 135/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0132 - val_accuracy: 0.9903 - val_loss: 0.0083
# Epoch 136/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0148 - val_accuracy: 0.9903 - val_loss: 0.0083
# Epoch 137/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9976 - loss: 0.0099 - val_accuracy: 0.9903 - val_loss: 0.0097
# Epoch 138/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0131 - val_accuracy: 0.9903 - val_loss: 0.0105
# Epoch 139/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.9903 - val_loss: 0.0099
# Epoch 140/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9853 - loss: 0.0354 - val_accuracy: 0.9903 - val_loss: 0.0144
# Epoch 141/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0183 - val_accuracy: 0.9903 - val_loss: 0.0139
# Epoch 142/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0212 - val_accuracy: 0.9903 - val_loss: 0.0126
# Epoch 143/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9976 - loss: 0.0127 - val_accuracy: 0.9903 - val_loss: 0.0091
# Epoch 144/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9976 - loss: 0.0110 - val_accuracy: 0.9903 - val_loss: 0.0094
# Epoch 145/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0170 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 146/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0181 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 147/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0149 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 148/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9976 - loss: 0.0108 - val_accuracy: 0.9903 - val_loss: 0.0094
# Epoch 149/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0215 - val_accuracy: 0.9903 - val_loss: 0.0099
# Epoch 150/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0147 - val_accuracy: 0.9903 - val_loss: 0.0102
# Epoch 151/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0125 - val_accuracy: 0.9903 - val_loss: 0.0133
# Epoch 152/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0177 - val_accuracy: 0.9903 - val_loss: 0.0151
# Epoch 153/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9903 - val_loss: 0.0132
# Epoch 154/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0116 - val_accuracy: 0.9903 - val_loss: 0.0090
# Epoch 155/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9976 - loss: 0.0108 - val_accuracy: 0.9903 - val_loss: 0.0085
# Epoch 156/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0164 - val_accuracy: 0.9903 - val_loss: 0.0087
# Epoch 157/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9878 - loss: 0.0228 - val_accuracy: 0.9903 - val_loss: 0.0118
# Epoch 158/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0203 - val_accuracy: 0.9903 - val_loss: 0.0165
# Epoch 159/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0121 - val_accuracy: 0.9903 - val_loss: 0.0145
# Epoch 160/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9878 - loss: 0.0212 - val_accuracy: 0.9903 - val_loss: 0.0141
# Epoch 161/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9976 - loss: 0.0095 - val_accuracy: 0.9903 - val_loss: 0.0118
# Epoch 162/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9976 - loss: 0.0090 - val_accuracy: 0.9903 - val_loss: 0.0111
# Epoch 163/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9903 - val_loss: 0.0104
# Epoch 164/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9951 - loss: 0.0122 - val_accuracy: 0.9903 - val_loss: 0.0115
# Epoch 165/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0156 - val_accuracy: 0.9903 - val_loss: 0.0122
# Epoch 166/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9951 - loss: 0.0140 - val_accuracy: 0.9903 - val_loss: 0.0130
# Epoch 167/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0100 - val_accuracy: 0.9903 - val_loss: 0.0128
# Epoch 168/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9976 - loss: 0.0081 - val_accuracy: 0.9903 - val_loss: 0.0132
# Epoch 169/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9976 - loss: 0.0080 - val_accuracy: 0.9903 - val_loss: 0.0132
# Epoch 170/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0117 - val_accuracy: 0.9903 - val_loss: 0.0125
# Epoch 171/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9976 - loss: 0.0088 - val_accuracy: 0.9903 - val_loss: 0.0130
# Epoch 172/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9903 - val_loss: 0.0123
# Epoch 173/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9903 - val_loss: 0.0120
# Epoch 174/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9903 - val_loss: 0.0105
# Epoch 175/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0085 - val_accuracy: 0.9903 - val_loss: 0.0080
# Epoch 176/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0104 - val_accuracy: 0.9903 - val_loss: 0.0081
# Epoch 177/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0128 - val_accuracy: 0.9903 - val_loss: 0.0090
# Epoch 178/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0105 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 179/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9927 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 180/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9976 - loss: 0.0062 - val_accuracy: 0.9903 - val_loss: 0.0088
# Epoch 181/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9976 - loss: 0.0086 - val_accuracy: 0.9903 - val_loss: 0.0120
# Epoch 182/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9976 - loss: 0.0069 - val_accuracy: 0.9903 - val_loss: 0.0091
# Epoch 183/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9903 - val_loss: 0.0080
# Epoch 184/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9976 - loss: 0.0080 - val_accuracy: 0.9903 - val_loss: 0.0081
# Epoch 185/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9903 - val_loss: 0.0112
# Epoch 186/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9927 - loss: 0.0146 - val_accuracy: 0.9903 - val_loss: 0.0102
# Epoch 187/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9976 - loss: 0.0066 - val_accuracy: 0.9903 - val_loss: 0.0105
# Epoch 188/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9903 - val_loss: 0.0109
# Epoch 189/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9903 - val_loss: 0.0094
# Epoch 190/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9951 - loss: 0.0106 - val_accuracy: 0.9903 - val_loss: 0.0111
# Epoch 191/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9951 - loss: 0.0100 - val_accuracy: 0.9903 - val_loss: 0.0108
# Epoch 192/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9903 - val_loss: 0.0104
# Epoch 193/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9903 - val_loss: 0.0097
# Epoch 194/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9903 - val_loss: 0.0074
# Epoch 195/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9976 - loss: 0.0070 - val_accuracy: 0.9903 - val_loss: 0.0075
# Epoch 196/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9903 - val_loss: 0.0093
# Epoch 197/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9976 - loss: 0.0061 - val_accuracy: 0.9903 - val_loss: 0.0113
# Epoch 198/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9976 - loss: 0.0057 - val_accuracy: 0.9903 - val_loss: 0.0113
# Epoch 199/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0101 - val_accuracy: 0.9903 - val_loss: 0.0111
# Epoch 200/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9903 - val_loss: 0.0090

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy']) # Access history from the 'history' object
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss']) # Access history from the 'history' object
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# Batch size defines number of samples that going to be propagated through the network.
#
# An Epoch is a complete pass through all the training data.

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)   # 0 - 1
y_pred = (y_pred >= 0.5)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step

# %%
# Confusion matrix with blue colors wiyh 6*5 fig size

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, cmap="Blues", annot=True, fmt='g')
plt.show()

# %%
# Classification report

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9714    0.9855        35
#            1     0.9565    1.0000    0.9778        22
#
#     accuracy                         0.9825        57
#    macro avg     0.9783    0.9857    0.9816        57
# weighted avg     0.9832    0.9825    0.9825        57
